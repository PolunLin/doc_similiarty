# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Show/Hide code"></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Show/Hide code"></form>

# %%
#### for dataframe interactive
# pip install qgrid==1.1.1
# jupyter nbextension enable --py --sys-prefix qgrid
# import qgrid
# # only required if you have not enabled the ipywidgets nbextension yet
# jupyter nbextension enable --py --sys-prefix widgetsnbextension
# #to show a df simply use the below:
# qgrid.show_grid(df)

# %% [markdown]
# # 0. Load package

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
from ckip_transformers.nlp import CkipWordSegmenter, CkipPosTagger, CkipNerChunker

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

document1 = ["（台灣英文新聞／醫藥組　綜合報導）中央流行疫情指揮中心今(4)日公布國內新增2例武漢肺炎（COVID-19）境外移入確定病例(案960、961)，分別自奈及利亞及菲律賓入境。",
"指揮中心表示，案960為奈及利亞籍50多歲男性，長期居住台灣，並持有我國居留證，今(2021)年1月8日返回奈及利亞奔喪，在當地曾於1月18日出現輕微咳嗽，經自行服藥後症狀緩解。",
"個案2月28日返台，持有搭機前3日內檢驗陰性報告，入境後至防疫旅館檢疫，3月2日因全身倦怠及有慢性病之就醫需求，由衛生單位安排就醫採檢，於今日確診。個案就醫時接觸之相關人員皆有適當防護，故無匡列接觸者。",
"案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性。",
"個案檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。",
"個案入境至今無症狀，已掌握個案接觸者共9人，其中同車移工8人未確實佩戴口罩，列居家隔離，司機1人因有適當防護，列自主健康管理。",
"指揮中心統計，截至目前國內累計960例確診，分別為844例境外移入，77例本土病例，36例敦睦艦隊、2例航空器感染及1例不明；另1例(案530)移除為空號。確診個案中9人死亡、928人解除隔離、23人住院隔離中。"]
document2 =["〔記者林惠琴／台北報導〕中央流行疫情指揮中心今日公布，武漢肺炎（新型冠狀病毒病，COVID-19）新增2例境外移入，分別自奈及利亞及菲律賓入境。",
"指揮中心發言人莊人祥表示，新增的案960為奈及利亞籍50多歲男性，長期居住台灣，並持有我國居留證，今年1月8日返回奈及利亞奔喪，在當地曾於1月18日出現輕微咳嗽，經自行服藥後症狀緩解。",
"該名個案2月28日返台，持有搭機前3日內檢驗陰性報告，入境後至防疫旅館檢疫，3月2日因全身倦怠及有慢性病之就醫需求，由衛生單位安排就醫採檢，於今日確診。就醫時接觸相關人員皆有適當防護，無匡列接觸者。",
"案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。",
"該名個案入境至今無症狀，已掌握個案接觸者共9人，其中同車移工8人未確實佩戴口罩，列居家隔離，司機1人因有適當防護，列自主健康管理。",
"指揮中心統計，截至目前國內累計960例武漢肺炎，分別為844例境外移入，77例本土病例，36例敦睦艦隊、2例航空器感染及1例不明；另1例（案530）移除為空號。確診個案中9人死亡、928人解除隔離、23人住院隔離中。",]
text = []
text.append(document1)
text.append(document2)

# print("文件一")
# for doc1 in document1:
#     print(doc1)
# print("文件二")
# for doc2 in document2:
#     print(doc2)
d = []
i = 0
for doc1 in document1:
    
    d.append(
        {
            'document id': "1",
            'sentence id': i,
            'content':  doc1
        }
    )
    i= i+1
    i = 0
for doc2 in document2:
    
    d.append(
        {
            'document id': "2",
            'sentence id': i,
            'content':  doc2
        }
    )
    i= i+1
pd.DataFrame(d)
pd.DataFrame(d).style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6" ><thead>    <tr>        <th class="col_heading level0 col0" >document id</th>        <th class="col_heading level0 col1" >sentence id</th>        <th class="col_heading level0 col2" >content</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row0_col2" class="data row0 col2" >（台灣英文新聞／醫藥組　綜合報導）中央流行疫情指揮中心今(4)日公布國內新增2例武漢肺炎（COVID-19）境外移入確定病例(案960、961)，分別自奈及利亞及菲律賓入境。</td>
#             </tr>
#             <tr>
#                                 <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row1_col1" class="data row1 col1" >0</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row1_col2" class="data row1 col2" >指揮中心表示，案960為奈及利亞籍50多歲男性，長期居住台灣，並持有我國居留證，今(2021)年1月8日返回奈及利亞奔喪，在當地曾於1月18日出現輕微咳嗽，經自行服藥後症狀緩解。</td>
#             </tr>
#             <tr>
#                                 <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row2_col0" class="data row2 col0" >1</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row2_col1" class="data row2 col1" >0</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row2_col2" class="data row2 col2" >個案2月28日返台，持有搭機前3日內檢驗陰性報告，入境後至防疫旅館檢疫，3月2日因全身倦怠及有慢性病之就醫需求，由衛生單位安排就醫採檢，於今日確診。個案就醫時接觸之相關人員皆有適當防護，故無匡列接觸者。</td>
#             </tr>
#             <tr>
#                                 <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row3_col0" class="data row3 col0" >1</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row3_col1" class="data row3 col1" >0</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row3_col2" class="data row3 col2" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性。</td>
#             </tr>
#             <tr>
#                                 <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row4_col0" class="data row4 col0" >1</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row4_col2" class="data row4 col2" >個案檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#             </tr>
#             <tr>
#                                 <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row5_col0" class="data row5 col0" >1</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row5_col2" class="data row5 col2" >個案入境至今無症狀，已掌握個案接觸者共9人，其中同車移工8人未確實佩戴口罩，列居家隔離，司機1人因有適當防護，列自主健康管理。</td>
#             </tr>
#             <tr>
#                                 <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row6_col0" class="data row6 col0" >1</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row6_col1" class="data row6 col1" >0</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row6_col2" class="data row6 col2" >指揮中心統計，截至目前國內累計960例確診，分別為844例境外移入，77例本土病例，36例敦睦艦隊、2例航空器感染及1例不明；另1例(案530)移除為空號。確診個案中9人死亡、928人解除隔離、23人住院隔離中。</td>
#             </tr>
#             <tr>
#                                 <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row7_col0" class="data row7 col0" >2</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row7_col1" class="data row7 col1" >0</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row7_col2" class="data row7 col2" >〔記者林惠琴／台北報導〕中央流行疫情指揮中心今日公布，武漢肺炎（新型冠狀病毒病，COVID-19）新增2例境外移入，分別自奈及利亞及菲律賓入境。</td>
#             </tr>
#             <tr>
#                                 <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row8_col0" class="data row8 col0" >2</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row8_col1" class="data row8 col1" >1</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row8_col2" class="data row8 col2" >指揮中心發言人莊人祥表示，新增的案960為奈及利亞籍50多歲男性，長期居住台灣，並持有我國居留證，今年1月8日返回奈及利亞奔喪，在當地曾於1月18日出現輕微咳嗽，經自行服藥後症狀緩解。</td>
#             </tr>
#             <tr>
#                                 <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row9_col0" class="data row9 col0" >2</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row9_col1" class="data row9 col1" >2</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row9_col2" class="data row9 col2" >該名個案2月28日返台，持有搭機前3日內檢驗陰性報告，入境後至防疫旅館檢疫，3月2日因全身倦怠及有慢性病之就醫需求，由衛生單位安排就醫採檢，於今日確診。就醫時接觸相關人員皆有適當防護，無匡列接觸者。</td>
#             </tr>
#             <tr>
#                                 <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row10_col0" class="data row10 col0" >2</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row10_col1" class="data row10 col1" >3</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row10_col2" class="data row10 col2" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#             </tr>
#             <tr>
#                                 <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row11_col0" class="data row11 col0" >2</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row11_col1" class="data row11 col1" >4</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row11_col2" class="data row11 col2" >該名個案入境至今無症狀，已掌握個案接觸者共9人，其中同車移工8人未確實佩戴口罩，列居家隔離，司機1人因有適當防護，列自主健康管理。</td>
#             </tr>
#             <tr>
#                                 <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row12_col0" class="data row12 col0" >2</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row12_col1" class="data row12 col1" >5</td>
#                         <td id="T_ba3d1fca_7fef_11eb_9ee7_6c6a776380b6row12_col2" class="data row12 col2" >指揮中心統計，截至目前國內累計960例武漢肺炎，分別為844例境外移入，77例本土病例，36例敦睦艦隊、2例航空器感染及1例不明；另1例（案530）移除為空號。確診個案中9人死亡、928人解除隔離、23人住院隔離中。</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # 2. Load CKIP model and Tokenization

# %%
ws_driver  = CkipWordSegmenter(level=3)
pos_driver = CkipPosTagger(level=3)
ner_driver = CkipNerChunker(level=3)

# %%
doc_ws= []

for doc in text:
    doc_ws.append(ws_driver(doc))
# Out:
# Tokenization: 100%|██████████| 7/7 [00:00<00:00, 1431.57it/s]
# Inference: 100%|██████████| 1/1 [00:01<00:00,  1.51s/it]
# Tokenization: 100%|██████████| 6/6 [00:00<00:00, 3073.50it/s]
# Inference: 100%|██████████| 1/1 [00:00<00:00,  1.21it/s]

# %%
d= []
document_id = 0
for doc,ws in zip(text,doc_ws):
    
    document_id =document_id+1
    for i in range(len(doc)):
        
        d.append(
        {
            'document id': document_id,
            'sentence id': i,
            'content':  doc[i],
            'token result' : ws[i]
        }
    )
pd.DataFrame(d)
df.style.hide_index()
        # print("document {}".format(i))
        # print(  doc[i],"\n",ws[i] )
# Out:
# <style  type="text/css" >
# </style><table id="T_c7e100c3_7fef_11eb_b5b2_6c6a776380b6" ><thead>    <tr>        <th class="col_heading level0 col0" >18日</th>        <th class="col_heading level0 col1" >19</th>        <th class="col_heading level0 col2" >1月</th>        <th class="col_heading level0 col3" >2021</th>        <th class="col_heading level0 col4" >20多</th>        <th class="col_heading level0 col5" >22日</th>        <th class="col_heading level0 col6" >23</th>        <th class="col_heading level0 col7" >26日</th>        <th class="col_heading level0 col8" >27日</th>        <th class="col_heading level0 col9" >28日</th>        <th class="col_heading level0 col10" >2日</th>        <th class="col_heading level0 col11" >2月</th>        <th class="col_heading level0 col12" >36</th>        <th class="col_heading level0 col13" >3月</th>        <th class="col_heading level0 col14" >50多</th>        <th class="col_heading level0 col15" >530</th>        <th class="col_heading level0 col16" >77</th>        <th class="col_heading level0 col17" >844</th>        <th class="col_heading level0 col18" >8日</th>        <th class="col_heading level0 col19" >928</th>        <th class="col_heading level0 col20" >960</th>        <th class="col_heading level0 col21" >961</th>        <th class="col_heading level0 col22" >9日</th>        <th class="col_heading level0 col23" >covid</th>        <th class="col_heading level0 col24" >不明</th>        <th class="col_heading level0 col25" >中央</th>        <th class="col_heading level0 col26" >中心</th>        <th class="col_heading level0 col27" >人員</th>        <th class="col_heading level0 col28" >今年</th>        <th class="col_heading level0 col29" >今日</th>        <th class="col_heading level0 col30" >仲介</th>        <th class="col_heading level0 col31" >住所</th>        <th class="col_heading level0 col32" >住院</th>        <th class="col_heading level0 col33" >佩戴</th>        <th class="col_heading level0 col34" >個案</th>        <th class="col_heading level0 col35" >倦怠</th>        <th class="col_heading level0 col36" >健康</th>        <th class="col_heading level0 col37" >先行</th>        <th class="col_heading level0 col38" >入境</th>        <th class="col_heading level0 col39" >全身</th>        <th class="col_heading level0 col40" >公布</th>        <th class="col_heading level0 col41" >冠狀病毒病</th>        <th class="col_heading level0 col42" >出現</th>        <th class="col_heading level0 col43" >分別</th>        <th class="col_heading level0 col44" >匡列</th>        <th class="col_heading level0 col45" >口罩</th>        <th class="col_heading level0 col46" >台北</th>        <th class="col_heading level0 col47" >台灣</th>        <th class="col_heading level0 col48" >司機</th>        <th class="col_heading level0 col49" >咳嗽</th>        <th class="col_heading level0 col50" >單位</th>        <th class="col_heading level0 col51" >國內</th>        <th class="col_heading level0 col52" >報告</th>        <th class="col_heading level0 col53" >報導</th>        <th class="col_heading level0 col54" >境外</th>        <th class="col_heading level0 col55" >奈及利亞</th>        <th class="col_heading level0 col56" >奈及利亞籍</th>        <th class="col_heading level0 col57" >奔喪</th>        <th class="col_heading level0 col58" >安排</th>        <th class="col_heading level0 col59" >專車</th>        <th class="col_heading level0 col60" >就醫</th>        <th class="col_heading level0 col61" >居住</th>        <th class="col_heading level0 col62" >居家</th>        <th class="col_heading level0 col63" >居留證</th>        <th class="col_heading level0 col64" >工作</th>        <th class="col_heading level0 col65" >感染</th>        <th class="col_heading level0 col66" >慢性病</th>        <th class="col_heading level0 col67" >我國</th>        <th class="col_heading level0 col68" >持有</th>        <th class="col_heading level0 col69" >指揮</th>        <th class="col_heading level0 col70" >掌握</th>        <th class="col_heading level0 col71" >採檢</th>        <th class="col_heading level0 col72" >接受</th>        <th class="col_heading level0 c ...
#                 <tr>
#                                 <td id="T_c7e100c3_7fef_11eb_b5b2_6c6a776380b6row0_col0" class="data row0 col0" >0</td>
#                         <td id

# %% [markdown]
# # 3. Similarity method compare
# 1. levenshtein & normalized_levenshtein
# 2. LongestCommonSubsequence & metric_lcs
# 3. Jaccard coefficient
# 4. Dice coefficient
# 5. Overlap coefficient
# 6. cosine similarity
#
# ## Method descrition
# 1. 首先我們有兩件文件，文件A以及文件B，將這兩個文件進行斷詞斷句。 *** 任務目標:檢測文件A 是否抄襲 (目前database 僅有一件文件B)
# 2. 將斷詞結果的list套入距離/相似度的演算法進行文件A的句子(7句)以及文件B的句子(六句)兩兩比較。
# 3. 將相似程度最高的句子內容以及相似分數/距離列出來(以文件A為基準，找到文件B當中相似度最高的句子)。
# 4. 將一樣的文字敘述透過顏色標註(疑問點:目前的作法是將文件B token內容直接丟進去，看是否有無在文件A token裡面，不考慮順序)

# %% [markdown]
# ## 1. levenshtein & normalized_levenshtein

# %%
# def highlight_greater(x):
#     r = 'red'
#     g = 'gray'

#     m1 = x['B'] > x['C']
#     m2 = x['D'] > x['E']

#     df1 = pd.DataFrame('background-color: ', index=x.index, columns=x.columns)
#     #rewrite values by boolean masks
#     df1['B'] = np.where(m1, 'background-color: {}'.format(r), df1['B'])
#     df1['D'] = np.where(m2, 'background-color: {}'.format(g), df1['D'])
#     return df1

## color
def in_statements(val):
    for statement in doc_ws[1][nlevenshtein.index(min(nlevenshtein))]:
        if statement in val:
            color = 'yellow'
            break
        else:
            color = 'black'
    return 'color: %s' % color

def color_in(val):
    if  '' in val:
        color = 'red'
    else:
        color = 'black'
    return 'color: %s' % color

# %%
# import distance
from strsimpy.levenshtein import Levenshtein ## https://github.com/luozhouyang/python-string-similarity
from strsimpy.normalized_levenshtein import NormalizedLevenshtein
doc1_index = 0
levenshtein = Levenshtein()
normalized_levenshtein = NormalizedLevenshtein()
d = []
for ws in doc_ws[0]:
    nlevenshtein=[]
    doc2_index= 0
    
    for ws_x in doc_ws[1]:
        
        # print(doc1_index,text[0][doc1_index])
        # print(doc2_index,text[1][doc2_index])  ## sentence & sentence pair compare
        # print("Levenshtein",distance.nlevenshtein(ws, ws_x))
        # hamming needs the same length strings
        
        # nlevenshtein.append(levenshtein.distance(ws, ws_x)) #levenshtein
        nlevenshtein.append(normalized_levenshtein.distance(ws, ws_x)) #normalized_levenshtein
        

        

        
        doc2_index+=1
    d .append(
        {
            'document1_sentence id': doc1_index,
            'document2_sentence id': nlevenshtein.index(min(nlevenshtein)),
            'document1 content': text[0][doc1_index],
            'document2 content': text[1][nlevenshtein.index(min(nlevenshtein))],
            'normalized_levenshtein':  min(nlevenshtein)
        }
    )

    # print(doc1_index,text[0][doc1_index])
    # print(nlevenshtein.index(min(nlevenshtein)),text[1][nlevenshtein.index(min(nlevenshtein))])
    # print("normalized_levenshtein",min(nlevenshtein)) 
    doc1_index+=1
pd.DataFrame(d)
pd.DataFrame(d).style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6" ><thead>    <tr>        <th class="col_heading level0 col0" >document1_sentence id</th>        <th class="col_heading level0 col1" >document2_sentence id</th>        <th class="col_heading level0 col2" >document1 content</th>        <th class="col_heading level0 col3" >document2 content</th>        <th class="col_heading level0 col4" >normalized_levenshtein</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row0_col2" class="data row0 col2" >（台灣英文新聞／醫藥組　綜合報導）中央流行疫情指揮中心今(4)日公布國內新增2例武漢肺炎（COVID-19）境外移入確定病例(案960、961)，分別自奈及利亞及菲律賓入境。</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row0_col3" class="data row0 col3" >〔記者林惠琴／台北報導〕中央流行疫情指揮中心今日公布，武漢肺炎（新型冠狀病毒病，COVID-19）新增2例境外移入，分別自奈及利亞及菲律賓入境。</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row0_col4" class="data row0 col4" >0.586957</td>
#             </tr>
#             <tr>
#                                 <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row1_col2" class="data row1 col2" >指揮中心表示，案960為奈及利亞籍50多歲男性，長期居住台灣，並持有我國居留證，今(2021)年1月8日返回奈及利亞奔喪，在當地曾於1月18日出現輕微咳嗽，經自行服藥後症狀緩解。</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row1_col3" class="data row1 col3" >指揮中心發言人莊人祥表示，新增的案960為奈及利亞籍50多歲男性，長期居住台灣，並持有我國居留證，今年1月8日返回奈及利亞奔喪，在當地曾於1月18日出現輕微咳嗽，經自行服藥後症狀緩解。</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row1_col4" class="data row1 col4" >0.163265</td>
#             </tr>
#             <tr>
#                                 <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row2_col1" class="data row2 col1" >2</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row2_col2" class="data row2 col2" >個案2月28日返台，持有搭機前3日內檢驗陰性報告，入境後至防疫旅館檢疫，3月2日因全身倦怠及有慢性病之就醫需求，由衛生單位安排就醫採檢，於今日確診。個案就醫時接觸之相關人員皆有適當防護，故無匡列接觸者。</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row2_col3" class="data row2 col3" >該名個案2月28日返台，持有搭機前3日內檢驗陰性報告，入境後至防疫旅館檢疫，3月2日因全身倦怠及有慢性病之就醫需求，由衛生單位安排就醫採檢，於今日確診。就醫時接觸相關人員皆有適當防護，無匡列接觸者。</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row2_col4" class="data row2 col4" >0.079365</td>
#             </tr>
#             <tr>
#                                 <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row3_col1" class="data row3 col1" >3</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row3_col2" class="data row3 col2" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性。</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row3_col3" class="data row3 col3" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row3_col4" class="data row3 col4" >0.516129</td>
#             </tr>
#             <tr>
#                                 <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row4_col1" class="data row4 col1" >3</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row4_col2" class="data row4 col2" >個案檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row4_col3" class="data row4 col3" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row4_col4" class="data row4 col4" >0.483871</td>
#             </tr>
#             <tr>
#                                 <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row5_col1" class="data row5 col1" >4</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row5_col2" class="data row5 col2" >個案入境至今無症狀，已掌握個案接觸者共9人，其中同車移工8人未確實佩戴口罩，列居家隔離，司機1人因有適當防護，列自主健康管理。</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row5_col3" class="data row5 col3" >該名個案入境至今無症狀，已掌握個案接觸者共9人，其中同車移工8人未確實佩戴口罩，列居家隔離，司機1人因有適當防護，列自主健康管理。</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row5_col4" class="data row5 col4" >0.044444</td>
#             </tr>
#             <tr>
#                                 <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row6_col0" class="data row6 col0" >6</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row6_col1" class="data row6 col1" >5</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row6_col2" class="data row6 col2" >指揮中心統計，截至目前國內累計960例確診，分別為844例境外移入，77例本土病例，36例敦睦艦隊、2例航空器感染及1例不明；另1例(案530)移除為空號。確診個案中9人死亡、928人解除隔離、23人住院隔離中。</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row6_col3" class="data row6 col3" >指揮中心統計，截至目前國內累計960例武漢肺炎，分別為844例境外移入，77例本土病例，36例敦睦艦隊、2例航空器感染及1例不明；另1例（案530）移除為空號。確診個案中9人死亡、928人解除隔離、23人住院隔離中。</td>
#                         <td id="T_c7fe4300_7fef_11eb_ad3e_6c6a776380b6row6_col4" class="data row6 col4" >0.086957</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## 2. LongestCommonSubsequence & metric_lcs

# %%
from strsimpy.longest_common_subsequence import LongestCommonSubsequence
from strsimpy.metric_lcs import MetricLCS
lcs = LongestCommonSubsequence()
metric_lcs = MetricLCS()
##1 - |LCS(s1, s2)| / max(|s1|, |s2|)
doc1_index = 0
d= []
for ws in doc_ws[0]:
    LCS=[]
    doc2_index= 0
    for ws_x in doc_ws[1]:
        
        # print(doc1_index,text[0][doc1_index])
        # print(doc2_index,text[1][doc2_index])  ## sentence & sentence pair compare
        # print("Levenshtein",distance.nlevenshtein(ws, ws_x))
        # hamming needs the same length strings
 
    
        # LCS.append(lcs.distance(ws, ws_x)) #LCS
        LCS.append(metric_lcs.distance(ws, ws_x)) #metric_lcs
        # print(metric_lcs.distance(s1, s2))
        doc2_index+=1
    d.append(
        {
            'document1_sentence id': doc1_index,
            'document2_sentence id': LCS.index(min(LCS)),
            'document1 content': text[0][doc1_index],
            'document2 content': text[1][LCS.index(min(LCS))],
            'metric_lcs': min(LCS),
            
        }
    )
    # print(doc1_index,text[0][doc1_index])
    # print(LCS.index(min(LCS)),text[1][LCS.index(min(LCS))])
    # print("metric_lcs",min(LCS)) 
    doc1_index+=1
pd.DataFrame(d)
pd.DataFrame(d).style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6" ><thead>    <tr>        <th class="col_heading level0 col0" >document1_sentence id</th>        <th class="col_heading level0 col1" >document2_sentence id</th>        <th class="col_heading level0 col2" >document1 content</th>        <th class="col_heading level0 col3" >document2 content</th>        <th class="col_heading level0 col4" >metric_lcs</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row0_col2" class="data row0 col2" >（台灣英文新聞／醫藥組　綜合報導）中央流行疫情指揮中心今(4)日公布國內新增2例武漢肺炎（COVID-19）境外移入確定病例(案960、961)，分別自奈及利亞及菲律賓入境。</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row0_col3" class="data row0 col3" >〔記者林惠琴／台北報導〕中央流行疫情指揮中心今日公布，武漢肺炎（新型冠狀病毒病，COVID-19）新增2例境外移入，分別自奈及利亞及菲律賓入境。</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row0_col4" class="data row0 col4" >0.521739</td>
#             </tr>
#             <tr>
#                                 <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row1_col2" class="data row1 col2" >指揮中心表示，案960為奈及利亞籍50多歲男性，長期居住台灣，並持有我國居留證，今(2021)年1月8日返回奈及利亞奔喪，在當地曾於1月18日出現輕微咳嗽，經自行服藥後症狀緩解。</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row1_col3" class="data row1 col3" >指揮中心發言人莊人祥表示，新增的案960為奈及利亞籍50多歲男性，長期居住台灣，並持有我國居留證，今年1月8日返回奈及利亞奔喪，在當地曾於1月18日出現輕微咳嗽，經自行服藥後症狀緩解。</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row1_col4" class="data row1 col4" >0.102041</td>
#             </tr>
#             <tr>
#                                 <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row2_col1" class="data row2 col1" >2</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row2_col2" class="data row2 col2" >個案2月28日返台，持有搭機前3日內檢驗陰性報告，入境後至防疫旅館檢疫，3月2日因全身倦怠及有慢性病之就醫需求，由衛生單位安排就醫採檢，於今日確診。個案就醫時接觸之相關人員皆有適當防護，故無匡列接觸者。</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row2_col3" class="data row2 col3" >該名個案2月28日返台，持有搭機前3日內檢驗陰性報告，入境後至防疫旅館檢疫，3月2日因全身倦怠及有慢性病之就醫需求，由衛生單位安排就醫採檢，於今日確診。就醫時接觸相關人員皆有適當防護，無匡列接觸者。</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row2_col4" class="data row2 col4" >0.047619</td>
#             </tr>
#             <tr>
#                                 <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row3_col1" class="data row3 col1" >3</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row3_col2" class="data row3 col2" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性。</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row3_col3" class="data row3 col3" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row3_col4" class="data row3 col4" >0.516129</td>
#             </tr>
#             <tr>
#                                 <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row4_col1" class="data row4 col1" >3</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row4_col2" class="data row4 col2" >個案檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row4_col3" class="data row4 col3" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row4_col4" class="data row4 col4" >0.483871</td>
#             </tr>
#             <tr>
#                                 <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row5_col1" class="data row5 col1" >4</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row5_col2" class="data row5 col2" >個案入境至今無症狀，已掌握個案接觸者共9人，其中同車移工8人未確實佩戴口罩，列居家隔離，司機1人因有適當防護，列自主健康管理。</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row5_col3" class="data row5 col3" >該名個案入境至今無症狀，已掌握個案接觸者共9人，其中同車移工8人未確實佩戴口罩，列居家隔離，司機1人因有適當防護，列自主健康管理。</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row5_col4" class="data row5 col4" >0.044444</td>
#             </tr>
#             <tr>
#                                 <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row6_col0" class="data row6 col0" >6</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row6_col1" class="data row6 col1" >5</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row6_col2" class="data row6 col2" >指揮中心統計，截至目前國內累計960例確診，分別為844例境外移入，77例本土病例，36例敦睦艦隊、2例航空器感染及1例不明；另1例(案530)移除為空號。確診個案中9人死亡、928人解除隔離、23人住院隔離中。</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row6_col3" class="data row6 col3" >指揮中心統計，截至目前國內累計960例武漢肺炎，分別為844例境外移入，77例本土病例，36例敦睦艦隊、2例航空器感染及1例不明；另1例（案530）移除為空號。確診個案中9人死亡、928人解除隔離、23人住院隔離中。</td>
#                         <td id="T_c807ef0e_7fef_11eb_afae_6c6a776380b6row6_col4" class="data row6 col4" >0.086957</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## 3. Jaccard coefficient

# %%
## jaccard

def Jaccrad(doc1, doc2):#terms_reference为源句子，terms_model为候选句子
    doc1 = set(doc1)
    doc2 = set(doc2)
    temp=0
    for i in doc1:
        if i in doc2:
            temp=temp+1
    fenmu=len(doc2)+len(doc1)-temp #聯集
    jaccard_coefficient=float(temp/fenmu)#交集
    return jaccard_coefficient
doc1_index = 0
d = []
for ws in doc_ws[0]:
    jaccard_=[]
    doc2_index= 0
    for ws_x in doc_ws[1]:
        

        jaccard_.append(Jaccrad(ws, ws_x)) #jaccard
        doc2_index+=1
    d.append(
        {
            'document1_sentence id': doc1_index,
            'document2_sentence id': jaccard_.index(max(jaccard_)),
            'document1 content': text[0][doc1_index],
            'document2 content': text[1][jaccard_.index(max(jaccard_))],
            'jaccard_coefficient': max(jaccard_),
            
        }
    )
    # print(doc1_index,text[0][doc1_index])
    # print(jaccard_.index(max(jaccard_)),text[1][jaccard_.index(max(jaccard_))])
    # print("jaccard_coefficient",max(jaccard_)) 
    doc1_index+=1

pd.DataFrame(d)
pd.DataFrame(d).style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6" ><thead>    <tr>        <th class="col_heading level0 col0" >document1_sentence id</th>        <th class="col_heading level0 col1" >document2_sentence id</th>        <th class="col_heading level0 col2" >document1 content</th>        <th class="col_heading level0 col3" >document2 content</th>        <th class="col_heading level0 col4" >jaccard_coefficient</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row0_col2" class="data row0 col2" >（台灣英文新聞／醫藥組　綜合報導）中央流行疫情指揮中心今(4)日公布國內新增2例武漢肺炎（COVID-19）境外移入確定病例(案960、961)，分別自奈及利亞及菲律賓入境。</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row0_col3" class="data row0 col3" >〔記者林惠琴／台北報導〕中央流行疫情指揮中心今日公布，武漢肺炎（新型冠狀病毒病，COVID-19）新增2例境外移入，分別自奈及利亞及菲律賓入境。</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row0_col4" class="data row0 col4" >0.462963</td>
#             </tr>
#             <tr>
#                                 <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row1_col2" class="data row1 col2" >指揮中心表示，案960為奈及利亞籍50多歲男性，長期居住台灣，並持有我國居留證，今(2021)年1月8日返回奈及利亞奔喪，在當地曾於1月18日出現輕微咳嗽，經自行服藥後症狀緩解。</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row1_col3" class="data row1 col3" >指揮中心發言人莊人祥表示，新增的案960為奈及利亞籍50多歲男性，長期居住台灣，並持有我國居留證，今年1月8日返回奈及利亞奔喪，在當地曾於1月18日出現輕微咳嗽，經自行服藥後症狀緩解。</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row1_col4" class="data row1 col4" >0.808511</td>
#             </tr>
#             <tr>
#                                 <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row2_col1" class="data row2 col1" >2</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row2_col2" class="data row2 col2" >個案2月28日返台，持有搭機前3日內檢驗陰性報告，入境後至防疫旅館檢疫，3月2日因全身倦怠及有慢性病之就醫需求，由衛生單位安排就醫採檢，於今日確診。個案就醫時接觸之相關人員皆有適當防護，故無匡列接觸者。</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row2_col3" class="data row2 col3" >該名個案2月28日返台，持有搭機前3日內檢驗陰性報告，入境後至防疫旅館檢疫，3月2日因全身倦怠及有慢性病之就醫需求，由衛生單位安排就醫採檢，於今日確診。就醫時接觸相關人員皆有適當防護，無匡列接觸者。</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row2_col4" class="data row2 col4" >0.943396</td>
#             </tr>
#             <tr>
#                                 <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row3_col1" class="data row3 col1" >3</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row3_col2" class="data row3 col2" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性。</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row3_col3" class="data row3 col3" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row3_col4" class="data row3 col4" >0.537313</td>
#             </tr>
#             <tr>
#                                 <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row4_col1" class="data row4 col1" >3</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row4_col2" class="data row4 col2" >個案檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row4_col3" class="data row4 col3" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row4_col4" class="data row4 col4" >0.602941</td>
#             </tr>
#             <tr>
#                                 <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row5_col1" class="data row5 col1" >4</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row5_col2" class="data row5 col2" >個案入境至今無症狀，已掌握個案接觸者共9人，其中同車移工8人未確實佩戴口罩，列居家隔離，司機1人因有適當防護，列自主健康管理。</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row5_col3" class="data row5 col3" >該名個案入境至今無症狀，已掌握個案接觸者共9人，其中同車移工8人未確實佩戴口罩，列居家隔離，司機1人因有適當防護，列自主健康管理。</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row5_col4" class="data row5 col4" >0.945946</td>
#             </tr>
#             <tr>
#                                 <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row6_col0" class="data row6 col0" >6</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row6_col1" class="data row6 col1" >5</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row6_col2" class="data row6 col2" >指揮中心統計，截至目前國內累計960例確診，分別為844例境外移入，77例本土病例，36例敦睦艦隊、2例航空器感染及1例不明；另1例(案530)移除為空號。確診個案中9人死亡、928人解除隔離、23人住院隔離中。</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row6_col3" class="data row6 col3" >指揮中心統計，截至目前國內累計960例武漢肺炎，分別為844例境外移入，77例本土病例，36例敦睦艦隊、2例航空器感染及1例不明；另1例（案530）移除為空號。確診個案中9人死亡、928人解除隔離、23人住院隔離中。</td>
#                         <td id="T_c80a9d50_7fef_11eb_aefc_6c6a776380b6row6_col4" class="data row6 col4" >0.851852</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## 4. Dice coefficient

# %%
## dice

def Dice(doc1, doc2):
    doc1 = set(doc1)
    doc2 = set(doc2)
    temp=0
    for i in doc1:
        if i in doc2:
            temp=temp+1
    dice_coefficient=float(2*temp/(len(doc2)+len(doc1)))#交集
    return dice_coefficient
doc1_index = 0
for ws in doc_ws[0]:
    dice_=[]
    doc2_index= 0
    for ws_x in doc_ws[1]:
        

        dice_.append(Dice(ws, ws_x)) #dice
        doc2_index+=1
    
    d.append(
        {
            'document1_sentence id': doc1_index,
            'document2_sentence id': dice_.index(max(dice_)),
            'document1 content': text[0][doc1_index],
            'document2 content': text[1][dice_.index(max(dice_))],
            'dice_coefficient': max(dice_),
            
        }
    )

    # print(doc1_index,text[0][doc1_index])
    # print(dice_.index(max(dice_)),text[1][dice_.index(max(dice_))])
    # print("dice_coefficient",max(dice_)) 
    doc1_index+=1


pd.DataFrame(d)
pd.DataFrame(d).style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6" ><thead>    <tr>        <th class="col_heading level0 col0" >document1_sentence id</th>        <th class="col_heading level0 col1" >document2_sentence id</th>        <th class="col_heading level0 col2" >document1 content</th>        <th class="col_heading level0 col3" >document2 content</th>        <th class="col_heading level0 col4" >jaccard_coefficient</th>        <th class="col_heading level0 col5" >dice_coefficient</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row0_col2" class="data row0 col2" >（台灣英文新聞／醫藥組　綜合報導）中央流行疫情指揮中心今(4)日公布國內新增2例武漢肺炎（COVID-19）境外移入確定病例(案960、961)，分別自奈及利亞及菲律賓入境。</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row0_col3" class="data row0 col3" >〔記者林惠琴／台北報導〕中央流行疫情指揮中心今日公布，武漢肺炎（新型冠狀病毒病，COVID-19）新增2例境外移入，分別自奈及利亞及菲律賓入境。</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row0_col4" class="data row0 col4" >0.462963</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row0_col5" class="data row0 col5" >nan</td>
#             </tr>
#             <tr>
#                                 <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row1_col2" class="data row1 col2" >指揮中心表示，案960為奈及利亞籍50多歲男性，長期居住台灣，並持有我國居留證，今(2021)年1月8日返回奈及利亞奔喪，在當地曾於1月18日出現輕微咳嗽，經自行服藥後症狀緩解。</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row1_col3" class="data row1 col3" >指揮中心發言人莊人祥表示，新增的案960為奈及利亞籍50多歲男性，長期居住台灣，並持有我國居留證，今年1月8日返回奈及利亞奔喪，在當地曾於1月18日出現輕微咳嗽，經自行服藥後症狀緩解。</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row1_col4" class="data row1 col4" >0.808511</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row1_col5" class="data row1 col5" >nan</td>
#             </tr>
#             <tr>
#                                 <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row2_col1" class="data row2 col1" >2</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row2_col2" class="data row2 col2" >個案2月28日返台，持有搭機前3日內檢驗陰性報告，入境後至防疫旅館檢疫，3月2日因全身倦怠及有慢性病之就醫需求，由衛生單位安排就醫採檢，於今日確診。個案就醫時接觸之相關人員皆有適當防護，故無匡列接觸者。</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row2_col3" class="data row2 col3" >該名個案2月28日返台，持有搭機前3日內檢驗陰性報告，入境後至防疫旅館檢疫，3月2日因全身倦怠及有慢性病之就醫需求，由衛生單位安排就醫採檢，於今日確診。就醫時接觸相關人員皆有適當防護，無匡列接觸者。</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row2_col4" class="data row2 col4" >0.943396</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row2_col5" class="data row2 col5" >nan</td>
#             </tr>
#             <tr>
#                                 <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row3_col1" class="data row3 col1" >3</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row3_col2" class="data row3 col2" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性。</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row3_col3" class="data row3 col3" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row3_col4" class="data row3 col4" >0.537313</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row3_col5" class="data row3 col5" >nan</td>
#             </tr>
#             <tr>
#                                 <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row4_col1" class="data row4 col1" >3</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row4_col2" class="data row4 col2" >個案檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row4_col3" class="data row4 col3" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row4_col4" class="data row4 col4" >0.602941</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row4_col5" class="data row4 col5" >nan</td>
#             </tr>
#             <tr>
#                                 <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row5_col1" class="data row5 col1" >4</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row5_col2" class="data row5 col2" >個案入境至今無症狀，已掌握個案接觸者共9人，其中同車移工8人未確實佩戴口罩，列居家隔離，司機1人因有適當防護，列自主健康管理。</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row5_col3" class="data row5 col3" >該名個案入境至今無症狀，已掌握個案接觸者共9人，其中同車移工8人未確實佩戴口罩，列居家隔離，司機1人因有適當防護，列自主健康管理。</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row5_col4" class="data row5 col4" >0.945946</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row5_col5" class="data row5 col5" >nan</td>
#             </tr>
#             <tr>
#                                 <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row6_col0" class="data row6 col0" >6</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row6_col1" class="data row6 col1" >5</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row6_col2" class="data row6 col2" >指揮中心統計，截至目前國內累計960例確診，分別為844例境外移入，77例本土病例，36例敦睦艦隊、2例航空器感染及1例不明；另1例(案530)移除為空號。確診個案中9人死亡、928人解除隔離、23人住院隔離中。</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row6_col3" class="data row6 col3" >指揮中心統計，截至目前國內累計960例武漢肺炎，分別為844例境外移入，77例本土病例，36例敦睦艦隊、2例航空器感染及1例不明；另1例（案530）移除為空號。確診個案中9人死亡、928人解除隔離、23人住院隔離中。</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row6_col4" class="data row6 col4" >0.851852</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row6_col5" class="data row6 col5" >nan</td>
#             </tr>
#             <tr>
#                                 <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row7_col0" class="data row7 col0" >0</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row7_col1" class="data row7 col1" >0</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row7_col2" class="data row7 col2" >（台灣英文新聞／醫藥組　綜合報導）中央流行疫情指揮中心今(4)日公布國內新增2例武漢肺炎（COVID-19）境外移入確定病例(案960、961)，分別自奈及利亞及菲律賓入境。</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row7_col3" class="data row7 col3" >〔記者林惠琴／台北報導〕中央流行疫情指揮中心今日公布，武漢肺炎（新型冠狀病毒病，COVID-19）新增2例境外移入，分別自奈及利亞及菲律賓入境。</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row7_col4" class="data row7 col4" >nan</td>
#                         <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row7_col5" class="data row7 col5" >0.632911</td>
#             </tr>
#             <tr>
#                                 <td id="T_c80cff56_7fef_11eb_9acd_6c6a776380b6row8_col0" class="data row8 col0" >1</td>
#                         <td i

# %% [markdown]
# ## 5. Overlap coefficient

# %%
## Overlap 

def Overlap(doc1, doc2):
    doc1 = set(doc1)
    doc2 = set(doc2)
    temp=0
    for i in doc1:
        if i in doc2:
            temp=temp+1
    overlap_coefficient=float(temp/(min(len(doc2),len(doc1))))#交集
    return overlap_coefficient
doc1_index = 0
d =[]
for ws in doc_ws[0]:
    overlap_=[]
    doc2_index= 0
    for ws_x in doc_ws[1]:
        

        overlap_.append(Overlap(ws, ws_x)) #dice
        doc2_index+=1
    d.append(
        {
            'document1_sentence id': doc1_index,
            'document2_sentence id': overlap_.index(max(overlap_)),
            'document1 content': text[0][doc1_index],
            'document2 content': text[1][overlap_.index(max(overlap_))],
            'overlap_coefficient': max(overlap_),
            
        }
    )
    # print(doc1_index,text[0][doc1_index])
    # print(overlap_.index(max(overlap_)),text[1][overlap_.index(max(overlap_))])
    # print("overlap_coefficient",max(overlap_)) 
    doc1_index+=1


pd.DataFrame(d)
pd.DataFrame(d).style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6" ><thead>    <tr>        <th class="col_heading level0 col0" >document1_sentence id</th>        <th class="col_heading level0 col1" >document2_sentence id</th>        <th class="col_heading level0 col2" >document1 content</th>        <th class="col_heading level0 col3" >document2 content</th>        <th class="col_heading level0 col4" >overlap_coefficient</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row0_col2" class="data row0 col2" >（台灣英文新聞／醫藥組　綜合報導）中央流行疫情指揮中心今(4)日公布國內新增2例武漢肺炎（COVID-19）境外移入確定病例(案960、961)，分別自奈及利亞及菲律賓入境。</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row0_col3" class="data row0 col3" >〔記者林惠琴／台北報導〕中央流行疫情指揮中心今日公布，武漢肺炎（新型冠狀病毒病，COVID-19）新增2例境外移入，分別自奈及利亞及菲律賓入境。</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row0_col4" class="data row0 col4" >0.714286</td>
#             </tr>
#             <tr>
#                                 <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row1_col2" class="data row1 col2" >指揮中心表示，案960為奈及利亞籍50多歲男性，長期居住台灣，並持有我國居留證，今(2021)年1月8日返回奈及利亞奔喪，在當地曾於1月18日出現輕微咳嗽，經自行服藥後症狀緩解。</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row1_col3" class="data row1 col3" >指揮中心發言人莊人祥表示，新增的案960為奈及利亞籍50多歲男性，長期居住台灣，並持有我國居留證，今年1月8日返回奈及利亞奔喪，在當地曾於1月18日出現輕微咳嗽，經自行服藥後症狀緩解。</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row1_col4" class="data row1 col4" >0.904762</td>
#             </tr>
#             <tr>
#                                 <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row2_col1" class="data row2 col1" >2</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row2_col2" class="data row2 col2" >個案2月28日返台，持有搭機前3日內檢驗陰性報告，入境後至防疫旅館檢疫，3月2日因全身倦怠及有慢性病之就醫需求，由衛生單位安排就醫採檢，於今日確診。個案就醫時接觸之相關人員皆有適當防護，故無匡列接觸者。</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row2_col3" class="data row2 col3" >該名個案2月28日返台，持有搭機前3日內檢驗陰性報告，入境後至防疫旅館檢疫，3月2日因全身倦怠及有慢性病之就醫需求，由衛生單位安排就醫採檢，於今日確診。就醫時接觸相關人員皆有適當防護，無匡列接觸者。</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row2_col4" class="data row2 col4" >0.980392</td>
#             </tr>
#             <tr>
#                                 <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row3_col1" class="data row3 col1" >3</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row3_col2" class="data row3 col2" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性。</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row3_col3" class="data row3 col3" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row3_col4" class="data row3 col4" >1.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row4_col1" class="data row4 col1" >3</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row4_col2" class="data row4 col2" >個案檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row4_col3" class="data row4 col3" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row4_col4" class="data row4 col4" >0.976190</td>
#             </tr>
#             <tr>
#                                 <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row5_col1" class="data row5 col1" >4</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row5_col2" class="data row5 col2" >個案入境至今無症狀，已掌握個案接觸者共9人，其中同車移工8人未確實佩戴口罩，列居家隔離，司機1人因有適當防護，列自主健康管理。</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row5_col3" class="data row5 col3" >該名個案入境至今無症狀，已掌握個案接觸者共9人，其中同車移工8人未確實佩戴口罩，列居家隔離，司機1人因有適當防護，列自主健康管理。</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row5_col4" class="data row5 col4" >1.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row6_col0" class="data row6 col0" >6</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row6_col1" class="data row6 col1" >5</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row6_col2" class="data row6 col2" >指揮中心統計，截至目前國內累計960例確診，分別為844例境外移入，77例本土病例，36例敦睦艦隊、2例航空器感染及1例不明；另1例(案530)移除為空號。確診個案中9人死亡、928人解除隔離、23人住院隔離中。</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row6_col3" class="data row6 col3" >指揮中心統計，截至目前國內累計960例武漢肺炎，分別為844例境外移入，77例本土病例，36例敦睦艦隊、2例航空器感染及1例不明；另1例（案530）移除為空號。確診個案中9人死亡、928人解除隔離、23人住院隔離中。</td>
#                         <td id="T_c80f3b36_7fef_11eb_80ec_6c6a776380b6row6_col4" class="data row6 col4" >0.938776</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## 6. cosine similarity
#
# ## Method implement
# - 因為 cosine similarity這個方法需要將文字轉成vector，所以將資料透過下列兩種方法嘗試
#     1. TF-IDF
#     2.  Doc2Vec
# - 疑問點:透過此類方法需要進行刪除停用句(甚至可以挑選POS的方式)，與上述方法比較並不公平?

# %%
## use space to tokenize
doc_ws_space = []
for doc in doc_ws:
    ws_space = []
    for word in doc:
        ws_space.append('  '.join(word))
    doc_ws_space.append(ws_space)

# %% [markdown]
# ### 1. cosine similarity with TF-IDF

# %%
# Scikit Learn
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

# tranditional chinese stopword 
stpwrdpath ="stopword.txt"
with open(stpwrdpath, 'rb') as fp:
    stopword = fp.read().decode('utf-8')  
stpwrdlst = stopword.splitlines()
count_vectorizer=CountVectorizer(stop_words=stpwrdlst) #建立詞袋資料結構
# Create the Document Term Matrix
sparse_matrix = count_vectorizer.fit_transform(doc_ws_space[0]+doc_ws_space[1])
# OPTIONAL: Convert Sparse Matrix to Pandas Dataframe if you want to see the word frequencies.
doc_term_matrix = sparse_matrix.todense()
df = pd.DataFrame(doc_term_matrix, 
                  columns=count_vectorizer.get_feature_names(), )

# %%
# Compute Cosine Similarity
from sklearn.metrics.pairwise import cosine_similarity
cosine_matrix = cosine_similarity(df, df)

# %%
# find the most similar document
sim= []
d = []
for index in range(len(doc_ws[0])):
    i = np.where(cosine_matrix[index][7:] ==max(cosine_matrix[index][7:]))
    # print(i)
    # print(text[0][index])
    # print(text[1][int(i[0])])
    # print(max(cosine_matrix[index][7:]))


    d.append(
        {
            'document1_sentence id': index,
            'document2_sentence id': int(i[0]),
            'document1 content': text[0][index],
            'document2 content': text[1][int(i[0])],
            'cosine_simliarty with TF-IDF': max(cosine_matrix[index][7:]),
            
        }
    )
    # print(doc1_index,text[0][doc1_index])
    # print(overlap_.index(max(overlap_)),text[1][overlap_.index(max(overlap_))])
    # print("overlap_coefficient",max(overlap_)) 
    doc1_index+=1


pd.DataFrame(d)
pd.DataFrame(d).style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6" ><thead>    <tr>        <th class="col_heading level0 col0" >document1_sentence id</th>        <th class="col_heading level0 col1" >document2_sentence id</th>        <th class="col_heading level0 col2" >document1 content</th>        <th class="col_heading level0 col3" >document2 content</th>        <th class="col_heading level0 col4" >cosine_simliarty with TF-IDF</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row0_col2" class="data row0 col2" >（台灣英文新聞／醫藥組　綜合報導）中央流行疫情指揮中心今(4)日公布國內新增2例武漢肺炎（COVID-19）境外移入確定病例(案960、961)，分別自奈及利亞及菲律賓入境。</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row0_col3" class="data row0 col3" >〔記者林惠琴／台北報導〕中央流行疫情指揮中心今日公布，武漢肺炎（新型冠狀病毒病，COVID-19）新增2例境外移入，分別自奈及利亞及菲律賓入境。</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row0_col4" class="data row0 col4" >0.669894</td>
#             </tr>
#             <tr>
#                                 <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row1_col2" class="data row1 col2" >指揮中心表示，案960為奈及利亞籍50多歲男性，長期居住台灣，並持有我國居留證，今(2021)年1月8日返回奈及利亞奔喪，在當地曾於1月18日出現輕微咳嗽，經自行服藥後症狀緩解。</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row1_col3" class="data row1 col3" >指揮中心發言人莊人祥表示，新增的案960為奈及利亞籍50多歲男性，長期居住台灣，並持有我國居留證，今年1月8日返回奈及利亞奔喪，在當地曾於1月18日出現輕微咳嗽，經自行服藥後症狀緩解。</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row1_col4" class="data row1 col4" >0.924062</td>
#             </tr>
#             <tr>
#                                 <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row2_col1" class="data row2 col1" >2</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row2_col2" class="data row2 col2" >個案2月28日返台，持有搭機前3日內檢驗陰性報告，入境後至防疫旅館檢疫，3月2日因全身倦怠及有慢性病之就醫需求，由衛生單位安排就醫採檢，於今日確診。個案就醫時接觸之相關人員皆有適當防護，故無匡列接觸者。</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row2_col3" class="data row2 col3" >該名個案2月28日返台，持有搭機前3日內檢驗陰性報告，入境後至防疫旅館檢疫，3月2日因全身倦怠及有慢性病之就醫需求，由衛生單位安排就醫採檢，於今日確診。就醫時接觸相關人員皆有適當防護，無匡列接觸者。</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row2_col4" class="data row2 col4" >0.989326</td>
#             </tr>
#             <tr>
#                                 <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row3_col1" class="data row3 col1" >3</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row3_col2" class="data row3 col2" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性。</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row3_col3" class="data row3 col3" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row3_col4" class="data row3 col4" >0.777781</td>
#             </tr>
#             <tr>
#                                 <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row4_col1" class="data row4 col1" >3</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row4_col2" class="data row4 col2" >個案檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row4_col3" class="data row4 col3" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row4_col4" class="data row4 col4" >0.773682</td>
#             </tr>
#             <tr>
#                                 <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row5_col1" class="data row5 col1" >4</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row5_col2" class="data row5 col2" >個案入境至今無症狀，已掌握個案接觸者共9人，其中同車移工8人未確實佩戴口罩，列居家隔離，司機1人因有適當防護，列自主健康管理。</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row5_col3" class="data row5 col3" >該名個案入境至今無症狀，已掌握個案接觸者共9人，其中同車移工8人未確實佩戴口罩，列居家隔離，司機1人因有適當防護，列自主健康管理。</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row5_col4" class="data row5 col4" >1.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row6_col0" class="data row6 col0" >6</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row6_col1" class="data row6 col1" >5</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row6_col2" class="data row6 col2" >指揮中心統計，截至目前國內累計960例確診，分別為844例境外移入，77例本土病例，36例敦睦艦隊、2例航空器感染及1例不明；另1例(案530)移除為空號。確診個案中9人死亡、928人解除隔離、23人住院隔離中。</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row6_col3" class="data row6 col3" >指揮中心統計，截至目前國內累計960例武漢肺炎，分別為844例境外移入，77例本土病例，36例敦睦艦隊、2例航空器感染及1例不明；另1例（案530）移除為空號。確診個案中9人死亡、928人解除隔離、23人住院隔離中。</td>
#                         <td id="T_cbc29d34_7fef_11eb_a3c0_6c6a776380b6row6_col4" class="data row6 col4" >0.929670</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### 2. cosine similarity with Doc2Vec

# %%
import gensim
from gensim.models.doc2vec import Doc2Vec, LabeledSentence
 
TaggededDocument = gensim.models.doc2vec.TaggedDocument



# tranditional chinese stopword 
stpwrdpath ="stopword.txt"
with open(stpwrdpath, 'rb') as fp:
    stopword = fp.read().decode('utf-8')  
stpwrdlst = stopword.splitlines()

## get trainning data  ### 只有丟文件B的資料
x_train = []
for i, content in enumerate(doc_ws[1]):
    word_list  = [word for word in content if not word in stpwrdlst]
    l = len(word_list)
    word_list[l - 1] = word_list[l - 1].strip()
    document = TaggededDocument(word_list, tags=[i])
    x_train.append(document)

### train model ### if you want to retrain model 
model = Doc2Vec(x_train, min_count=1, window=3, size=200, sample=1e-3, negative=5, workers=4)
model.train(x_train, total_examples=model.corpus_count, epochs=70)
# model.save('model/model')


## test 文件A 資料
# model = Doc2Vec.load("model/model")
d = []
    #句子向量化操作
for i,doc in enumerate(doc_ws[0]):
    word_list  = [word for word in doc if not word in stpwrdlst]
    inferred_vector = model.infer_vector(word_list)
    sim = model.docvecs.most_similar([inferred_vector], topn=1)
    # sims.append(sim)
    
    d.append(
        {
            'document1_sentence id': i,
            'document2_sentence id': sim[0][0],
            'document1 content': text[0][i],
            'document2 content': text[1][sim[0][0]],
            'cosine_simliarty with TF-IDF': sim[0][1],
            
        }
    )
    # # print(doc1_index,text[0][doc1_index])
    # # print(overlap_.index(max(overlap_)),text[1][overlap_.index(max(overlap_))])
    # # print("overlap_coefficient",max(overlap_)) 
    # doc1_index+=1


pd.DataFrame(d)
pd.DataFrame(d).style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6" ><thead>    <tr>        <th class="col_heading level0 col0" >document1_sentence id</th>        <th class="col_heading level0 col1" >document2_sentence id</th>        <th class="col_heading level0 col2" >document1 content</th>        <th class="col_heading level0 col3" >document2 content</th>        <th class="col_heading level0 col4" >cosine_simliarty with TF-IDF</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row0_col1" class="data row0 col1" >3</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row0_col2" class="data row0 col2" >（台灣英文新聞／醫藥組　綜合報導）中央流行疫情指揮中心今(4)日公布國內新增2例武漢肺炎（COVID-19）境外移入確定病例(案960、961)，分別自奈及利亞及菲律賓入境。</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row0_col3" class="data row0 col3" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row0_col4" class="data row0 col4" >0.999642</td>
#             </tr>
#             <tr>
#                                 <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row1_col1" class="data row1 col1" >3</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row1_col2" class="data row1 col2" >指揮中心表示，案960為奈及利亞籍50多歲男性，長期居住台灣，並持有我國居留證，今(2021)年1月8日返回奈及利亞奔喪，在當地曾於1月18日出現輕微咳嗽，經自行服藥後症狀緩解。</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row1_col3" class="data row1 col3" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row1_col4" class="data row1 col4" >0.999624</td>
#             </tr>
#             <tr>
#                                 <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row2_col1" class="data row2 col1" >3</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row2_col2" class="data row2 col2" >個案2月28日返台，持有搭機前3日內檢驗陰性報告，入境後至防疫旅館檢疫，3月2日因全身倦怠及有慢性病之就醫需求，由衛生單位安排就醫採檢，於今日確診。個案就醫時接觸之相關人員皆有適當防護，故無匡列接觸者。</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row2_col3" class="data row2 col3" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row2_col4" class="data row2 col4" >0.999656</td>
#             </tr>
#             <tr>
#                                 <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row3_col1" class="data row3 col1" >3</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row3_col2" class="data row3 col2" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性。</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row3_col3" class="data row3 col3" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row3_col4" class="data row3 col4" >0.999772</td>
#             </tr>
#             <tr>
#                                 <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row4_col1" class="data row4 col1" >3</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row4_col2" class="data row4 col2" >個案檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row4_col3" class="data row4 col3" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row4_col4" class="data row4 col4" >0.999781</td>
#             </tr>
#             <tr>
#                                 <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row5_col1" class="data row5 col1" >3</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row5_col2" class="data row5 col2" >個案入境至今無症狀，已掌握個案接觸者共9人，其中同車移工8人未確實佩戴口罩，列居家隔離，司機1人因有適當防護，列自主健康管理。</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row5_col3" class="data row5 col3" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row5_col4" class="data row5 col4" >0.999622</td>
#             </tr>
#             <tr>
#                                 <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row6_col0" class="data row6 col0" >6</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row6_col1" class="data row6 col1" >3</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row6_col2" class="data row6 col2" >指揮中心統計，截至目前國內累計960例確診，分別為844例境外移入，77例本土病例，36例敦睦艦隊、2例航空器感染及1例不明；另1例(案530)移除為空號。確診個案中9人死亡、928人解除隔離、23人住院隔離中。</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row6_col3" class="data row6 col3" >案961為菲律賓籍20多歲男性移工，今年2月9日來台工作，持有搭機前3日內檢驗陰性報告，入境後至集中檢疫所檢疫，2月22日接受檢疫期滿前採檢，結果為陰性，檢疫期滿後，由仲介安排至其他住所自主健康管理，2月26日搭乘專車至醫院自費採檢，因核酸檢測未確定，27日先行收治住院隔離，同日及3月2日進行核酸檢驗，於今日確診。</td>
#                         <td id="T_db7019c4_7fef_11eb_bd5f_6c6a776380b6row6_col4" class="data row6 col4" >0.999583</td>
#             </tr>
#     </tbody></table>
